# %% [markdown]
# ##### Import necessary library

# %% [markdown]
# https://shorturl.at/BUBRi Link to the dataset
# https://shorturl.at/1g8Qw to this notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ##### Description of two categories

# %%
apple_features = {
    'Color Intensity': [90, 85, 95, 88, 92],
    'Surface Texture': [1, 0.8, 0.9, 0.8, 0.9]            # Smooth surface
}

orange_features = {
    'Color Intensity': [80, 85, 75, 70, 78],
    'Surface Texture': [0.5, 0.4, 0.2, 0.5, 0.4]            # Bumpy surface
}

# %% [markdown]
# ##### Conversion to dataframe

# %%
apple_df = pd.DataFrame(apple_features)
orange_df = pd.DataFrame(orange_features)

# %%
apple_df
# Out:
#    Color Intensity  Surface Texture
# 0               90              1.0
# 1               85              0.8
# 2               95              0.9
# 3               88              0.8
# 4               92              0.9

# %%
orange_df
# Out:
#    Color Intensity  Surface Texture
# 0               80              0.5
# 1               85              0.4
# 2               75              0.2
# 3               70              0.5
# 4               78              0.4

# %% [markdown]
# ##### Feature vector of unknown categories in numpy array

# %%
apple = apple_df.to_numpy()
orange = orange_df.to_numpy()

# %%
print("feature of apple")
print(apple)
print()
print("feature of orange")

print(orange)
# Out:
# feature of apple
# [[90.   1. ]
#  [85.   0.8]
#  [95.   0.9]
#  [88.   0.8]
#  [92.   0.9]]
#
# feature of orange
# [[80.   0.5]
#  [85.   0.4]
#  [75.   0.2]
#  [70.   0.5]
#  [78.   0.4]]

# %%
apple[:,0]
# Out:
# array([90., 85., 95., 88., 92.])

# %%
apple[:,1]
# Out:
# array([1. , 0.8, 0.9, 0.8, 0.9])

# %% [markdown]
# ##### Feature vector of unknown categories

# %%
new_category_features = {
    'Color Intensity': [85],
    'Surface Texture': [0.5]
}

# %%
new_category_features = pd.DataFrame(new_category_features)

# %%
new_category_features
# Out:
#    Color Intensity  Surface Texture
# 0               85              0.5

# %%
new_featurevector = new_category_features.to_numpy()

# %%
new_featurevector
# Out:
# array([[85. ,  0.5]])

# %%
new_featurevector[:,0]
# Out:
# array([85.])

# %% [markdown]
# ##### visualization

# %%
plt.figure(figsize=(8,6))
plt.plot(apple[:,0],apple[:,1],"*",label="apple")
plt.plot(orange[:,0],orange[:,1],"^",label="orange")
plt.plot(new_featurevector[:,0],new_featurevector[:,1],"x",label="new example")
plt.legend(loc='upper right')
plt.xlabel("length")
plt.ylabel("width")

plt.xlim(65, 100)  # Adjust based on your data
plt.ylim(-0.5, 1.5)  # Adjust based on your data
# Out:
# (-0.5, 1.5)

# %% [markdown]
# ##### Euclidean distance

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
new_featurevector[0,1]
# Out:
# 0.5

# %%
for a in apple:
    print(a[1])
# Out:
# 1.0
# 0.8
# 0.9
# 0.8
# 0.9

# %%
new_featurevector
# Out:
# array([[85. ,  0.5]])

# %%
def euclidean_dist(x1,x2,y1,y2):
    return ((x2-x1)**2+(y2-y1)**2)**0.5
print("new cateogy distance in space from apple")

for a in apple:
    print(euclidean_dist(new_featurevector[0,0],a[0],new_featurevector[0,1],a[1]))
print()
print("new cateogy distance in space from orange")

for o in orange:
    print(euclidean_dist(new_featurevector[0,0],o[0],new_featurevector[0,1],o[1]))
# Out:
# new cateogy distance in space from apple
# 5.024937810560445
# 0.30000000000000004
# 10.007996802557443
# 3.014962686336267
# 7.011419257183241
#
# new cateogy distance in space from orange
# 5.0
# 0.09999999999999998
# 10.004498987955369
# 15.0
# 7.000714249274855

# %% [markdown]
# DIY:
#     Do the task using Manhattan

# %%
def manhattan_dist(x1,x2,y1,y2):
    return (abs(x2-x1)+abs(y2-y1))
print("new cateogy distance in space from apple")

for a in apple:
    print(manhattan_dist(new_featurevector[0,0],a[0],new_featurevector[0,1],a[1]))
print()
print("new cateogy distance in space from orange")

for o in orange:
    print(manhattan_dist(new_featurevector[0,0],o[0],new_featurevector[0,1],o[1]))
# Out:
# new cateogy distance in space from apple
# 5.5
# 0.30000000000000004
# 10.4
# 3.3
# 7.4
#
# new cateogy distance in space from orange
# 5.0
# 0.09999999999999998
# 10.3
# 15.0
# 7.1

# %% [markdown]
# #### Do it yourself (workshop 1)
# - Convert each varible to dataframe
# - Convert datafrafe to numpy array
# - demonstrate datapoint in 3d view using mpl_toolkits.mplot3d

# %%
a_grade_grapes = {
    'Color Intensity': [85, 88, 90, 87, 89],     # High color intensity
    'Surface Texture': [0.2, 0.25, 0.22, 0.24, 0.21],  # Very smooth surface
    'Sugar Content': [18.5, 19.0, 19.2, 18.8, 19.1]  # High sugar content
}

b_grade_grapes = {
    'Color Intensity': [75, 78, 80, 77, 79],     # Moderate color intensity
    'Surface Texture': [0.3, 0.35, 0.33, 0.34, 0.31],  # Smooth surface
    'Sugar Content': [15.0, 15.5, 15.2, 15.1, 15.4]  # Moderate sugar content
}

c_grade_grapes = {
    'Color Intensity': [60, 65, 63, 62, 64],     # Lower color intensity
    'Surface Texture': [0.4, 0.42, 0.41, 0.39, 0.43],  # Rougher surface
    'Sugar Content': [12.0, 12.5, 12.2, 12.1, 12.3]  # Lower sugar content
}
new = {
    'Color Intensity': [62],     # Lower color intensity
    'Surface Texture': [0.9],  # Rougher surface
    'Sugar Content': [12.1]  # Lower sugar content
}

# %%
a_grade_grapes = pd.DataFrame(a_grade_grapes)
b_grade_grapes = pd.DataFrame(b_grade_grapes)
c_grade_grapes = pd.DataFrame(c_grade_grapes)

# %%
new = pd.DataFrame(new)

# %%
a_grade_grapes
# Out:
#    Color Intensity  Surface Texture  Sugar Content
# 0               85             0.20           18.5
# 1               88             0.25           19.0
# 2               90             0.22           19.2
# 3               87             0.24           18.8
# 4               89             0.21           19.1

# %% [markdown]
# ##### hint for 3d plot

# %%
a_grade_grapes = a_grade_grapes.to_numpy()
b_grade_grapes = b_grade_grapes.to_numpy()
c_grade_grapes = c_grade_grapes.to_numpy()
new = new.to_numpy()

# %%
a_grade_grapes
# Out:
# array([[85.  ,  0.2 , 18.5 ],
#        [88.  ,  0.25, 19.  ],
#        [90.  ,  0.22, 19.2 ],
#        [87.  ,  0.24, 18.8 ],
#        [89.  ,  0.21, 19.1 ]])

# %%
def euclidean_dist(x1,x2,y1,y2,z1,z2):
    return ((x2-x1)**2+(y2-y1)**2+(z2-z1)**2)**0.5
print("new cateogy distance in space from apple")

for data_point in a_grade_grapes:
    print(euclidean_dist(new[0,0],data_point[0],new[0,1],data_point[1],new[0,2],data_point[2]))
print("new cateogy distance in space from a_grade_grapes")

for data_point in c_grade_grapes:
    print(euclidean_dist(new[0,0],data_point[0],new[0,1],data_point[1],new[0,2],data_point[2]))
print("new cateogy distance in space from b_grade_grapes")

for data_point in c_grade_grapes:
    print(euclidean_dist(new[0,0],data_point[0],new[0,1],data_point[1],new[0,2],data_point[2]))
print("new cateogy distance in space from c_grade_grapes")
# Out:
# new cateogy distance in space from apple
# 23.884095126255048
# 26.90785201386391
# 28.894158579200745
# 25.890646959857918
# 27.90118456266687
# new cateogy distance in space from a_grade_grapes
# 2.0639767440550294
# 3.0643759560471686
# 1.1180787092150535
# 0.51
# 2.0641947582532034
# new cateogy distance in space from b_grade_grapes
# 2.0639767440550294
# 3.0643759560471686
# 1.1180787092150535
# 0.51
# 2.0641947582532034
# new cateogy distance in space from c_grade_grapes

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(a_grade_grapes[:, 0], a_grade_grapes[:, 1], a_grade_grapes[:, 2], marker='*', label='a_grade_grapes', color='red')
ax.scatter(b_grade_grapes[:, 0], b_grade_grapes[:, 1], b_grade_grapes[:, 2], marker='*', label='a_grade_grapes', color='yellow')
ax.scatter(c_grade_grapes[:, 0], c_grade_grapes[:, 1], c_grade_grapes[:, 2], marker='*', label='a_grade_grapes', color='blue')


ax.set_xlabel('Length')
ax.set_ylabel('Width')
ax.set_zlabel('Third Feature')
ax.legend(loc='upper right')



# Show the plot
plt.show()

# %%
import pandas as pd

# %%
df=pd.read_csv("disease.csv")

# %%
df.sample(6)
# Out:
#       Unnamed: 0          a          b Category
# 11            11  96.990985  49.383400    dis_a
# 1937        1937  58.377278   8.011280    dis_b
# 1336        1336  45.623651  45.411424    dis_b
# 217          217  74.649141  34.024965    dis_a
# 478          478  96.930254  39.890682    dis_a
# 233          233  49.251769   1.556704    dis_a

# %%
df.shape
# Out:
# (2000, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2000 non-null   int64
#  1   a           2000 non-null   float64
#  2   b           2000 non-null   float64
#  3   Category    2000 non-null   object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 62.6+ KB

# %%
df = df.drop('Unnamed: 0', axis='columns')
df.sample(5)
# Out:
#               a          b Category
# 1382  91.663524   1.557455    dis_b
# 1332  60.379545   8.494050    dis_b
# 1589  71.395263   9.820961    dis_b
# 1296  21.906881  32.415900    dis_b
# 503   81.379502  17.062391    dis_a

# %% [markdown]
# ##### Scikit-learn is a powerful open-source machine learning library
# ##### It offers a wide range of algorithms and functionalities tools for various machine learning tasks.
# ##### It is utilized by both beginners and experienced practitioners.

# %% [markdown]
# # installation

# %% [markdown]
# pip install scikit-learn

# %% [markdown]
# ##### Train_test_split

# %% [markdown]
# ##### Purpose:To divide your dataset into two parts: one for training the model and one for testing its performance.

# %%
independent_columns = df[['a', 'b']]  # Features
dependent_column = df['Category']  # Labels

# %%
independent_columns.head()
# Out:
#            a          b
# 0  37.454012   9.256646
# 1  95.071431  27.095047
# 2  73.199394  43.647292
# 3  59.865848  36.611244
# 4  15.601864  40.328057

# %%
dependent_column.head()
# Out:
# 0    dis_a
# 1    dis_a
# 2    dis_a
# 3    dis_a
# 4    dis_a
# Name: Category, dtype: object

# %%
from sklearn.model_selection import train_test_split # this is used for splitting the dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(independent_columns, dependent_column, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (1600, 2)

# %%
X_test.shape
# Out:
# (400, 2)

# %%
# test_size=0.2
# random_state=42

# %%
X_train,y_train
# Out:
# (array([[56.64046403, 16.72556444],
#         [94.04585844, 43.4311584 ],
#         [33.51972416, 19.09698198],
#         ...,
#         [77.55276167, 38.82237232],
#         [40.17788007, 32.43194784],
#         [63.46712733, 33.64358343]]),
#  array(['dis_a', 'dis_a', 'dis_a', ..., 'dis_a', 'dis_b', 'dis_b'],
#        dtype=object))

# %%
X_train.shape,y_train.shape
# Out:
# ((1600, 2), (1600,))

# %%
X_test.shape,y_test.shape
# Out:
# ((400, 2), (400,))

# %% [markdown]
# #### KNeighborsClassifier

# %% [markdown]
# ##### Supervised k-NN:
# ##### This uses the k-NN algorithm for classification tasks.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X_train, y_train) # .fit method is used for training the algorithm.
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
X_test.to_numpy()[5]
# Out:
# array([65.22242595, 26.78282997])

# %%
y_test.to_numpy()[5]
# Out:
# 'dis_b'

# %%
predicted_class = knn.predict(X_test.to_numpy()[5].reshape(1, -1)) # reshape will convert the 1d datapoint into 2d.
predicted_class
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['dis_a'], dtype=object)

# %%
predicted_probabilities = knn.predict_proba(X_test.to_numpy()[4].reshape(1, -1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
print("Predicted class:", predicted_class)
print("Predicted class probabilities:", predicted_probabilities)
# Out:
# Predicted class: ['dis_a']
# Predicted class probabilities: [[0.57142857 0.42857143]]

# %%
predicted_class = knn.predict(X_test[350].reshape(1, -1))
predicted_probabilities = knn.predict_proba(X_test[350].reshape(1, -1))
print("Predicted class:", predicted_class)
print("Predicted class probabilities:", predicted_probabilities)
# Out:
# Predicted class: ['dis_b']
# Predicted class probabilities: [[0. 1.]]

# %%
predicted_class = knn.predict(X_test[200].reshape(1, -1))
predicted_probabilities = knn.predict_proba(X_test[200].reshape(1, -1))
print("Predicted class:", predicted_class)
print("Predicted class probabilities:", predicted_probabilities)
# Out:
# Predicted class: ['dis_a']
# Predicted class probabilities: [[0.66666667 0.33333333]]

# %%
accuracy = knn.score(X_test, y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 53.75%

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_pred = knn.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[102  97]
#  [105  96]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        dis_a       0.53      0.55      0.54       199
#        dis_b       0.54      0.52      0.53       201
#
#     accuracy                           0.54       400
#    macro avg       0.54      0.54      0.54       400
# weighted avg       0.54      0.54      0.54       400

# %% [markdown]
# ##### Loading default dataset from scikit learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import numpy as np

iris_data = load_iris() #load the iris dataset
X = iris_data.data
y = iris_data.target
print(len(X)) #print number of examples
# Out:
# 150

# %%
type(iris_data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
df = pd.DataFrame(data=iris_data.data, columns=iris_data.feature_names)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['species'] = iris_data.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 5 columns]

# %%
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##### do it youself
# - Solve using KNeighborsClassifier

# %%
df=pd.read_csv("loan_defaulter_data.csv")

# %%
df
# Out:
#      Age  Income  Loan_Amount  Credit_Score  Employment_Status  Defaulter
# 0     56   69376       331033           679                  1          1
# 1     46   65587       155893           520                  0          0
# 2     32   56976       431783           719                  1          0
# 3     60  124587       116374           423                  1          0
# 4     25  147534        25860           721                  0          0
# ..   ...     ...          ...           ...                ...        ...
# 995   23  142901       494158           764                  0          0
# 996   43   40953        55823           403                  0          1
# 997   21   96919        24312           801                  1          0
# 998   36  134682       437324           474                  0          0
# 999   37  141041       461134           720                  1          0
#
# [1000 rows x 6 columns]
